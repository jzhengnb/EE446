# %% [markdown]
# # EE446 - TinyML - Assignment 2

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, accuracy_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from tensorflow.keras import datasets, layers,models
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.keras import regularizers
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")
from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score
import c_writer
from os.path import join

# %% [markdown]
# ## Reading Data

# %%
# Reading the data and adding column header (feature) names
data = pd.read_csv("Network_anomaly_data.txt",sep=",",names=["duration","protocoltype","service",
"flag","srcbytes","dstbytes","land", "wrongfragment","urgent","hot","numfailedlogins","loggedin", "numcompromised",
"rootshell","suattempted","numroot","numfilecreations", "numshells","numaccessfiles","numoutboundcmds","ishostlogin",
"isguestlogin","count","srvcount","serrorrate", "srvserrorrate","rerrorrate","srvrerrorrate","samesrvrate",
"diffsrvrate", "srvdiffhostrate","dsthostcount","dsthostsrvcount","dsthostsamesrvrate", "dsthostdiffsrvrate",
"dsthostsamesrcportrate","dsthostsrvdiffhostrate","dsthostserrorrate","dsthostsrvserrorrate","dsthostrerrorrate",
"dsthostsrvrerrorrate","attack", "lastflag"])

# %%
data # printing the dataframe
# Out:
#         duration protocoltype   service flag  srcbytes  dstbytes  land  \
# 0              0          tcp  ftp_data   SF       491         0     0
# 1              0          udp     other   SF       146         0     0
# 2              0          tcp   private   S0         0         0     0
# 3              0          tcp      http   SF       232      8153     0
# 4              0          tcp      http   SF       199       420     0
# ...          ...          ...       ...  ...       ...       ...   ...
# 125968         0          tcp   private   S0         0         0     0
# 125969         8          udp   private   SF       105       145     0
# 125970         0          tcp      smtp   SF      2231       384     0
# 125971         0          tcp    klogin   S0         0         0     0
# 125972         0          tcp  ftp_data   SF       151         0     0
#
#         wrongfragment  urgent  hot  ...  dsthostsamesrvrate  \
# 0                   0       0    0  ...                0.17
# 1                   0       0    0  ...                0.00
# 2                   0       0    0  ...                0.10
# 3                   0       0    0  ...                1.00
# 4                   0       0    0  ...                1.00
# ...               ...     ...  ...  ...                 ...
# 125968              0       0    0  ...                0.10
# 125969              0       0    0  ...                0.96
# 125970              0       0    0  ...                0.12
# 125971              0       0    0  ...                0.03
# 125972              0       0    0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate   attack  lastflag
# 0                       0.00   normal        20
# 1                       0.00   normal        15
# 2                       0.00  neptune        19
# 3                       0.01   normal        21
# 4                       0.00   normal        21
# ...                      ...      ...       ...
# 125968                  0.00  neptune        20
# 125969                  0.00   normal        21
# 125970                  0.00   normal        18
# 125971                  0.00  neptune        20
# 125972                  0.00   normal        21
#
# [125973 rows x 43 columns]

# %% [markdown]
# ## Question 1: Data Preprocessing

# %% [markdown]
# ##### (a) Drop the 'land', 'urgent', 'numfailedlogins', 'numoutboundcmds' columns from the dataframe "data".

# %%
## INSERT YOUR CODE HERE ##
data = data.drop(['land', 'urgent', 'numfailedlogins', 'numoutboundcmds'], axis=1)

# %% [markdown]
# ##### (b) Change any label that is not named normal to attack in the {'attack'} column of the dataframe data.

# %%
## INSERT YOUR CODE HERE ##
data['attack'] = data['attack'].apply(lambda x: 'normal' if x == 'normal' else 'attack')

# %%
data #<--------- Print your modified dataframe "data"
# Out:
#         duration protocoltype   service flag  srcbytes  dstbytes  \
# 0              0          tcp  ftp_data   SF       491         0
# 1              0          udp     other   SF       146         0
# 2              0          tcp   private   S0         0         0
# 3              0          tcp      http   SF       232      8153
# 4              0          tcp      http   SF       199       420
# ...          ...          ...       ...  ...       ...       ...
# 125968         0          tcp   private   S0         0         0
# 125969         8          udp   private   SF       105       145
# 125970         0          tcp      smtp   SF      2231       384
# 125971         0          tcp    klogin   S0         0         0
# 125972         0          tcp  ftp_data   SF       151         0
#
#         wrongfragment  hot  loggedin  numcompromised  ...  dsthostsamesrvrate  \
# 0                   0    0         0               0  ...                0.17
# 1                   0    0         0               0  ...                0.00
# 2                   0    0         0               0  ...                0.10
# 3                   0    0         1               0  ...                1.00
# 4                   0    0         1               0  ...                1.00
# ...               ...  ...       ...             ...  ...                 ...
# 125968              0    0         0               0  ...                0.10
# 125969              0    0         0               0  ...                0.96
# 125970              0    0         1               0  ...                0.12
# 125971              0    0         0               0  ...                0.03
# 125972              0    0         1               0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate  attack  lastflag
# 0                       0.00  normal        20
# 1                       0.00  normal        15
# 2                       0.00  attack        19
# 3                       0.01  normal        21
# 4                       0.00  normal        21
# ...                      ...     ...       ...
# 125968                  0.00  attack        20
# 125969                  0.00  normal        21
# 125970                  0.00  normal        18
# 125971                  0.00  attack        20
# 125972                  0.00  normal        21
#
# [125973 rows x 39 columns]

# %% [markdown]
# ##### (c) Use LabelEncoder() function from the sklearn.preprocessing library to convert non-numerical attributes in the {'protocoltype', 'service', 'flag', 'attack'} columns of the dataframe data to numerical values.

# %%
## INSERT YOUR CODE HERE ##
le = LabelEncoder()
for col in ['protocoltype', 'service', 'flag', 'attack']:
    data[col] = le.fit_transform(data[col])

# %%
pd.DataFrame(data) #<--------- Print your modified dataframe "data"
# Out:
#         duration  protocoltype  service  flag  srcbytes  dstbytes  \
# 0              0             1       20     9       491         0
# 1              0             2       44     9       146         0
# 2              0             1       49     5         0         0
# 3              0             1       24     9       232      8153
# 4              0             1       24     9       199       420
# ...          ...           ...      ...   ...       ...       ...
# 125968         0             1       49     5         0         0
# 125969         8             2       49     9       105       145
# 125970         0             1       54     9      2231       384
# 125971         0             1       30     5         0         0
# 125972         0             1       20     9       151         0
#
#         wrongfragment  hot  loggedin  numcompromised  ...  dsthostsamesrvrate  \
# 0                   0    0         0               0  ...                0.17
# 1                   0    0         0               0  ...                0.00
# 2                   0    0         0               0  ...                0.10
# 3                   0    0         1               0  ...                1.00
# 4                   0    0         1               0  ...                1.00
# ...               ...  ...       ...             ...  ...                 ...
# 125968              0    0         0               0  ...                0.10
# 125969              0    0         0               0  ...                0.96
# 125970              0    0         1               0  ...                0.12
# 125971              0    0         0               0  ...                0.03
# 125972              0    0         1               0  ...                0.30
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 0                     0.03                    0.17                    0.00
# 1                     0.60                    0.88                    0.00
# 2                     0.05                    0.00                    0.00
# 3                     0.00                    0.03                    0.04
# 4                     0.00                    0.00                    0.00
# ...                    ...                     ...                     ...
# 125968                0.06                    0.00                    0.00
# 125969                0.01                    0.01                    0.00
# 125970                0.06                    0.00                    0.00
# 125971                0.05                    0.00                    0.00
# 125972                0.03                    0.30                    0.00
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 0                    0.00                  0.00               0.05
# 1                    0.00                  0.00               0.00
# 2                    1.00                  1.00               0.00
# 3                    0.03                  0.01               0.00
# 4                    0.00                  0.00               0.00
# ...                   ...                   ...                ...
# 125968               1.00                  1.00               0.00
# 125969               0.00                  0.00               0.00
# 125970               0.72                  0.00               0.01
# 125971               1.00                  1.00               0.00
# 125972               0.00                  0.00               0.00
#
#         dsthostsrvrerrorrate  attack  lastflag
# 0                       0.00       1        20
# 1                       0.00       1        15
# 2                       0.00       0        19
# 3                       0.01       1        21
# 4                       0.00       1        21
# ...                      ...     ...       ...
# 125968                  0.00       0        20
# 125969                  0.00       1        21
# 125970                  0.00       1        18
# 125971                  0.00       0        20
# 125972                  0.00       1        21
#
# [125973 rows x 39 columns]

# %% [markdown]
# ## Feature Scaling and Train/Test Split

# %%
# All the features apart from Attack are what we are going to use to predict the attack status of the data
# attack = 1 (normal/not an attack) and attack = 0 (attack)
X = data.drop(['attack'],axis=1).to_numpy()

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
X_normalized = scaler.fit_transform(X)

Y = data['attack'].to_numpy()
# Splitting X and y testing and training data
# we are taking 20% of the data for testing and 80% of the data for training
X_train, X_test, y_train, y_test = train_test_split(X_normalized, Y, test_size = 0.20)
# reshaping y test and train array
y_train = y_train.reshape(len(y_train),1)
y_test = y_test.reshape(len(y_test),1)

# %% [markdown]
# ## Question 2: Dimensionality Reduction for Visualization

# %% [markdown]
# ##### (a) Use TSNE from the sklearn.manifold library to visualize the data in the test set (X_test) in 2D. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
from sklearn.manifold import TSNE
## INSERT YOUR CODE HERE ##

y_test_flat = y_test.ravel()

tsne = TSNE(n_components=2, random_state=42, perplexity=30)
X_tsne = tsne.fit_transform(X_test)

plt.figure(figsize=(8, 6))

plt.scatter(
    X_tsne[y_test_flat == 0, 0],
    X_tsne[y_test_flat == 0, 1],
    c='red',
    label='Attack',
    s=10,
    alpha=0.6
)

plt.scatter(
    X_tsne[y_test_flat == 1, 0],
    X_tsne[y_test_flat == 1, 1],
    c='blue',
    label='Normal',
    s=10,
    alpha=0.6
)

plt.title("t-SNE Visualization of Test Data")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.legend()
plt.show()

# %% [markdown]
# ##### (b) Use PCA from the sklearn.decomposition library to visualize the data in the test set (X_test) in 2D. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
from sklearn.decomposition import PCA
## INSERT YOUR CODE HERE ##

y_test_flat = y_test.ravel()

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_test)

plt.figure(figsize=(8, 6))

plt.scatter(
    X_pca[y_test_flat == 0, 0],
    X_pca[y_test_flat == 0, 1],
    c='red',
    label='Attack',
    s=10,
    alpha=0.6
)

plt.scatter(
    X_pca[y_test_flat == 1, 0],
    X_pca[y_test_flat == 1, 1],
    c='blue',
    label='Normal',
    s=10,
    alpha=0.6
)

plt.title("PCA Visualization of Test Data")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend()
plt.show()

# %% [markdown]
# ##### (c) Use KernelPCA from the sklearn.decomposition library to visualize the data in the test set (X_test) in 2D. Use radial basis function (rbf) as the kernel. In your figure, use color "red" to mark {attack} data points and color "blue" to mark {normal} data points.

# %%
from sklearn.decomposition import KernelPCA
## INSERT YOUR CODE HERE ##

y_test_flat = y_test.ravel()

kpca = KernelPCA(n_components=2, kernel='rbf')
X_kpca = kpca.fit_transform(X_test)

plt.figure(figsize=(8, 6))

plt.scatter(
    X_kpca[y_test_flat == 0, 0],
    X_kpca[y_test_flat == 0, 1],
    c='red',
    label='Attack',
    s=10,
    alpha=0.6
)

plt.scatter(
    X_kpca[y_test_flat == 1, 0],
    X_kpca[y_test_flat == 1, 1],
    c='blue',
    label='Normal',
    s=10,
    alpha=0.6
)

plt.title("Kernel PCA Visualization of Test Data")
plt.xlabel("Kernel PCA Component 1")
plt.ylabel("Kernel PCA Component 2")
plt.legend()
plt.show()

# %% [markdown]
# ## Question 3: Implementing a DNN on the dataset

# %% [markdown]
# ##### (a) Implement a deep neural network (DNN) on the Network Anomaly Dataset. Ensure to include two neurons and softmax activation in the output layer of your DNN.

# %%
# Define the DNN model
base_model = Sequential([
    ## INSERT YOUR CODE HERE ##
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(2, activation='softmax')
])

# %% [markdown]
# ##### (b) Compile and train your DNN model on the training set (X_train). Denote the trained model as base_model.

# %%
## INSERT YOUR CODE HERE ##

# Compile the model
base_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = base_model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/20
# 2520/2520 [==============================] - 1s 392us/step - loss: 0.0278 - accuracy: 0.9912 - val_loss: 0.0178 - val_accuracy: 0.9959
# Epoch 2/20
# 2520/2520 [==============================] - 1s 370us/step - loss: 0.0110 - accuracy: 0.9959 - val_loss: 0.0090 - val_accuracy: 0.9973
# Epoch 3/20
# 2520/2520 [==============================] - 1s 369us/step - loss: 0.0079 - accuracy: 0.9969 - val_loss: 0.0075 - val_accuracy: 0.9979
# Epoch 4/20
# 2520/2520 [==============================] - 1s 370us/step - loss: 0.0062 - accuracy: 0.9975 - val_loss: 0.0097 - val_accuracy: 0.9979
# Epoch 5/20
# 2520/2520 [==============================] - 1s 370us/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0071 - val_accuracy: 0.9982
# Epoch 6/20
# 2520/2520 [==============================] - 1s 371us/step - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.0076 - val_accuracy: 0.9990
# Epoch 7/20
# 2520/2520 [==============================] - 1s 369us/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0084 - val_accuracy: 0.9984
# Epoch 8/20
# 2520/2520 [==============================] - 1s 369us/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0071 - val_accuracy: 0.9979
# Epoch 9/20
# 2520/2520 [==============================] - 1s 371us/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.0066 - val_accuracy: 0.9984
# Epoch 10/20
# 2520/2520 [==============================] - 1s 370us/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0038 - val_accuracy: 0.9988
# Epoch 11/20
# 2520/2520 [==============================] - 1s 370us/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0090 - val_accuracy: 0.9988
# Epoch 12/20
# 2520/2520 [==============================] - 1s 369us/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0064 - val_accuracy: 0.9980
# Epoch 13/20
# 2520/2520 [==============================] - 1s 369us/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0041 - val_accuracy: 0.9986
# Epoch 14/20
# 2520/2520 [==============================] - 1s 369us/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.0077 - val_accuracy: 0.9987
# Epoch 15/20
# 2520/2520 [==============================] - 1s 369us/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.0069 - val_accuracy: 0.9985
# Epoch 16/20
# 2520/2520 [==============================] - 1s 370us/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.0129 - val_accuracy: 0.9984
# Epoch 17/20
# 2520/2520 [==============================] - 1s 371us/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.0096 - val_accuracy: 0.9979
# Epoch 18/20
# 2520/2520 [==============================] - 1s 369us/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0131 - val_accuracy: 0.9982
# Epoch 19/20
# 2520/2520 [==============================] - 1s 370us/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0086 - val_accuracy: 0.9985
# Epoch 20/20
# 2520/2520 [==============================] - 1s 369us/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0106 - val_accuracy: 0.9987

# %% [markdown]
# ##### (c) Evaluate the base_model on the test set (X_test) using classification_report and confusion_matrix from the sklearn.metrics library. Report these numbers in your .pdf writeup file using screenshots.

# %%
## INSERT YOUR CODE HERE ##

# Evaluate the model on the test set
test_loss, test_accuracy = base_model.evaluate(X_test, y_test, verbose=0)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

# Predict class probabilities
base_pred_prob = base_model.predict(X_test)

# Convert probabilities to class labels
base_pred = np.argmax(base_pred_prob, axis=1)

# Flatten y_test
y_true = y_test.ravel()

class_names = ["attack", "normal"]

print("DNN Classification Report:")
print(classification_report(y_true, base_pred, target_names=class_names))

cm_base = confusion_matrix(y_true, base_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_base, display_labels=class_names)

fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, xticks_rotation=45, cmap="Blues", colorbar=False)
plt.title("Confusion Matrix for DNN Model")
plt.tight_layout()
plt.show()
# Out:
# Test Loss: 0.005318243522197008
# Test Accuracy: 0.9986901879310608
# 788/788 [==============================] - 0s 214us/step
# DNN Classification Report:
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00     11643
#       normal       1.00      1.00      1.00     13552
#
#     accuracy                           1.00     25195
#    macro avg       1.00      1.00      1.00     25195
# weighted avg       1.00      1.00      1.00     25195

# %%
# Save the original Keras model to HDF5 file
base_model.save('original_model.h5')

# %% [markdown]
# ## Question 4: Implementing Quantized Model

# %% [markdown]
# ##### (a) Implement Dynamic Range Quantization on the base_model. Designate the resulting quantized ML model as tflite_quant_model.

# %%
# Load the trained model
base_model = tf.keras.models.load_model('original_model.h5')

## INSERT YOUR CODE HERE ##
# Convert the base model to a TFLite model with dynamic range quantization
converter = tf.lite.TFLiteConverter.from_keras_model(base_model)

# Apply default optimization for dynamic range quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Convert the model
tflite_quant_model = converter.convert()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# INFO:tensorflow:Assets written to: /var/folders/z6/7022w09s7z97jc93g594sz940000gn/T/tmp63fwhs5c/assets
# INFO:tensorflow:Assets written to: /var/folders/z6/7022w09s7z97jc93g594sz940000gn/T/tmp63fwhs5c/assets
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RestoredOptimizer` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RestoredOptimizer`.
# 2026-05-22 15:07:33.681441: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2026-05-22 15:07:33.681454: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2026-05-22 15:07:33.681532: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /var/folders/z6/7022w09s7z97jc93g594sz940000gn/T/tmp63fwhs5c
# 2026-05-22 15:07:33.681946: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2026-05-22 15:07:33.681950: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /var/folders/z6/7022w09s7z97jc93g594sz940000gn/T/tmp63fwhs5c
# 2026-05-22 15:07:33.683115: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2026-05-22 15:07:33.698300: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /var/folders/z6/7022w09s7z97jc93g594sz940000gn/T/tmp63fwhs5c
# 2026-05-22 15:07:33.702635: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 21103 microseconds.

# %%
import os

# Save the quantized model
with open('quantized_model.tflite', 'wb') as f:
    f.write(tflite_quant_model)

# Get the file sizes
original_model_size = os.path.getsize('original_model.h5')
quantized_model_size = os.path.getsize('quantized_model.tflite')

# Print the model sizes
print(f"Original model size: {original_model_size / 1024:.2f} KB")
print(f"Quantized model size: {quantized_model_size / 1024:.2f} KB")
# Out:
# Original model size: 100.01 KB
# Quantized model size: 9.54 KB

# %% [markdown]
# ##### (b) Evaluate the tflite_quant_model on the test set (X_test) using classification_report and confusion_matrix from the sklearn.metrics library. Report these numbers in your .pdf writeup file using screenshots.

# %%
## INSERT YOUR CODE HERE ##

# Load the quantized TFLite model
interpreter = tf.lite.Interpreter(model_path='quantized_model.tflite')
interpreter.allocate_tensors()

# Get input and output tensor details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Store predictions
quant_pred = []

# Run inference on the test set
for i in range(len(X_test)):
    input_data = X_test[i:i+1].astype(np.float32)

    interpreter.set_tensor(input_details[0]['index'], input_data)
    interpreter.invoke()

    output_data = interpreter.get_tensor(output_details[0]['index'])
    pred_label = np.argmax(output_data, axis=1)[0]

    quant_pred.append(pred_label)

# Convert predictions to numpy array
quant_pred = np.array(quant_pred)

# Flatten y_test
y_true = y_test.ravel()

# Class names based on LabelEncoder encoding
class_names = ["attack", "normal"]

print("Dynamic Range Quantized Model Classification Report:")
print(classification_report(y_true, quant_pred, target_names=class_names))

cm_quant = confusion_matrix(y_true, quant_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_quant, display_labels=class_names)

fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, xticks_rotation=45, cmap="Blues", colorbar=False)
plt.title("Confusion Matrix for Dynamic Range Quantized Model")
plt.tight_layout()
plt.show()
# Out:
# Dynamic Range Quantized Model Classification Report:
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00     11643
#       normal       1.00      1.00      1.00     13552
#
#     accuracy                           1.00     25195
#    macro avg       1.00      1.00      1.00     25195
# weighted avg       1.00      1.00      1.00     25195

# %% [markdown]
# ## Converting tflite_model to C and create the header file

# %%
# c_writer is a py file in the same folder and has been imported at the beginning of the notebook
# Reference : https://github.com/ShawnHymel/tinyml-example-anomaly-detection/blob/master/utils/c_writer.py
# We use #04x to pad the output to 2 digits with a 0x prefix
hex_array = [format(val, '#04x') for val in tflite_quant_model]
# Calling function to convert an array into a C string (requires Numpy)
# create_array(np_array, var_type, var_name, line_limit=80, indent=4)
c_model = c_writer.create_array(np.array(hex_array), 'unsigned char', "network_model")
# Calling Function to create a header file with given C code as a string
header_str = c_writer.create_header(c_model, "network_model")

# %%
#Writing to the header file
with open('network_model.h', 'w') as file:
    file.write(header_str)

# %% [markdown]
# ## Generating Samples for Inference on Arduino

# %%
# Converting a sample piece of the X test and y test data to C (for the purpose of ino code (arduino) to load and test
# the sample and compare

Xtest = X_test[5:15, :]
print(c_writer.create_array(Xtest, "float", "X_test"))
# Out:
# const unsigned int X_test_dim1 = 10;
# const unsigned int X_test_dim2 = 38;
#
# const float X_test[10][38] = {
#     -0.11024922321249885, -0.12470615670462065, -0.6256096769302915,
#     -0.7362346401101137, -0.00776224074056876, -0.004918644383724874,
#     -0.08948642202040107, -0.09507567152556495, -0.8092618187059747,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     1.7543942522415594, -0.06522822763449025, 1.602663889932865,
#     1.6051037177847889, -0.37436223991967527, -0.37443160310530493,
#     -1.3214280114927377, -0.07238850323553762, -0.37455970440553465,
#     0.7343425609306344, -0.8369564484773167, -0.9605613486815793,
#     -0.17441734820805624, -0.4801968475158174, -0.28910340026287856,
#     1.6087590765792643, 1.6189552037455606, -0.38763462350750655,
#     -0.3763870260680415, 0.21642633142264128, -0.11024922321249885,
#     -0.12470615670462065, -0.747960738063091, -0.7362346401101137,
#     -0.00776224074056876, -0.004918644383724874, -0.08948642202040107,
#     -0.09507567152556495, -0.8092618187059747, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, 1.5710011970213902,
#     -0.14783240546059254, 1.602663889932865, 1.6051037177847889,
#     -0.37436223991967527, -0.37443160310530493, -1.366921731434956,
#     -0.016929597707948767, -0.37455970440553465, 0.7343425609306344,
#     -0.9363220430671004, -1.0496586099715604, -0.06855302025511306,
#     -0.4801968475158174, -0.28910340026287856, 1.6087590765792643,
#     1.6189552037455606, -0.38763462350750655, -0.3763870260680415,
#     0.21642633142264128, -0.10410602127184165, -0.12470615670462065,
#     1.7602360151593, 0.7511112872365361, -0.007737369813364,
#     -0.003594679005846673, -0.08948642202040107, -0.09507567152556495,
#     1.2356940323701657, -0.011663642603760032, -0.036651869142258646,
#     -0.024436507262009306, -0.01238515036740332, -0.02618002418454278,
#     -0.018609896340735923, -0.04122119759327531, -0.0028174939213690777,
#     -0.0975309439715147, -0.7257784945454897, -0.3681102129968653,
#     -0.6372092679572258, -0.6319290328885425, -0.37436223991967527,
#     -0.37443160310530493, 0.7712831058493207, -0.349683030873482,
#     -0.37455970440553465, -1.8259911156502953, -1.0266544017850858,
#     1.0664013456654926, -0.43907816809041417, 2.756092007079775,
#     8.594782234054632, -0.6395319051152512, -0.6248707997445304,
#     -0.38763462350750655, 1.188763348292702, -0.21997021516886575,
#     -0.11024922321249885, -0.12470615670462065, -0.44208308523109213,
#     0.7511112872365361, -0.007727659930825155, -0.0034101594133625207,
#     -0.08948642202040107, -0.09507567152556495, 1.2356940323701657,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     -0.708312489286426, -0.17536713140262664, -0.6372092679572258,
#     -0.6319290328885425, -0.37436223991967527, -0.37443160310530493,
#     0.7712831058493207, -0.349683030873482, 0.39517593198755846,
#     -1.1103072926690116, 1.2587542737799418, 1.0664013456654926,
#     -0.43907816809041417, -0.4478339589698615, -0.02258683123335326,
#     -0.6395319051152512, -0.6248707997445304, -0.38763462350750655,
#     -0.3763870260680415, 0.6528228780141483, -0.11024922321249885,
#     -2.468724163053645, -0.9926628603286901, 0.7511112872365361,
#     -0.007586440761970732, -0.004918644383724874, -0.08948642202040107,
#     -0.09507567152556495, -0.8092618187059747, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, 3.7280528465157605,
#     6.639477539250813, -0.6372092679572258, -0.6319290328885425,
#     -0.37436223991967527, -0.37443160310530493, 0.7712831058493207,
#     -0.349683030873482, -0.37455970440553465, 0.7343425609306344,
#     0.11153331806152875, -0.047314420459272144, -0.17441734820805624,
#     1.137947579781979, -0.28910340026287856, -0.6395319051152512,
#     -0.6248707997445304, -0.38763462350750655, -0.3763870260680415,
#     0.21642633142264128, -0.11024922321249885, -0.12470615670462065,
#     -0.44208308523109213, 0.7511112872365361, -0.0077111360956274725,
#     -0.0038886172246017504, -0.08948642202040107, -0.09507567152556495,
#     1.2356940323701657, -0.011663642603760032, -0.036651869142258646,
#     -0.024436507262009306, -0.01238515036740332, -0.02618002418454278,
#     -0.018609896340735923, -0.04122119759327531, -0.0028174939213690777,
#     -0.0975309439715147, -0.708312489286426, -0.3405754870548312,
#     0.10194887414650415, 0.10629177483365683, -0.37436223991967527,
#     -0.37443160310530493, 0.7712831058493207, -0.349683030873482,
#     -0.37455970440553465, -1.8058310079606816, 1.2587542737799418,
#     1.0664013456654926, -0.43907816809041417, 0.5877784745007281,
#     -0.02258683123335326, 0.10240411884393899, -0.6248707997445304,
#     -0.38763462350750655, -0.3763870260680415, -0.6563667617603728,
#     -0.11024922321249885, -0.12470615670462065, 1.3931828317609012,
#     0.7511112872365361, -0.007607052968763718, -0.004835585699237399,
#     -0.08948642202040107, -0.09507567152556495, 1.2356940323701657,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     -0.7257784945454897, -0.3681102129968653, -0.6372092679572258,
#     -0.6319290328885425, -0.37436223991967527, -0.37443160310530493,
#     0.7712831058493207, -0.349683030873482, -0.37455970440553465,
#     -1.5235895003060909, 0.47286275293346985, 0.9995783996980065,
#     -0.12148518423158469, -0.38310818187794965, -0.20026454391970344,
#     -0.6395319051152512, -0.6248707997445304, -0.2897732983676676,
#     -0.251174996119182, 0.6528228780141483, -0.11024922321249885,
#     -0.12470615670462065, -0.44208308523109213, 0.7511112872365361,
#     -0.007723571559229853, -0.00484528416838414, -0.08948642202040107,
#     -0.09507567152556495, 1.2356940323701657, -0.011663642603760032,
#     -0.036651869142258646, -0.024436507262009306, -0.01238515036740332,
#     -0.02618002418454278, -0.018609896340735923, -0.04122119759327531,
#     -0.0028174939213690777, -0.0975309439715147, -0.7170454919159579,
#     -0.35434285002584825, -0.6372092679572258, -0.6319290328885425,
#     -0.37436223991967527, -0.37443160310530493, 0.7712831058493207,
#     -0.349683030873482, -0.37455970440553465, -0.7474253542559666,
#     1.2587542737799418, 1.0664013456654926, -0.43907816809041417,
#     -0.4478339589698615, -0.11142568757652836, -0.6395319051152512,
#     -0.6248707997445304, -0.38763462350750655, -0.3763870260680415,
#     0.6528228780141483, -0.11024922321249885, -0.12470615670462065,
#     2.127289198557699, -0.7362346401101137, -0.00776224074056876,
#     -0.004918644383724874, -0.08948642202040107, -0.09507567152556495,
#     -0.8092618187059747, -0.011663642603760032, -0.036651869142258646,
#     -0.024436507262009306, -0.01238515036740332, -0.02618002418454278,
#     -0.018609896340735923, -0.04122119759327531, -0.0028174939213690777,
#     -0.0975309439715147, 0.4706428657003756, -0.17536713140262664,
#     1.602663889932865, 1.6051037177847889, -0.37436223991967527,
#     -0.37443160310530493, -1.2531874315794096, -0.016929597707948767,
#     -0.37455970440553465, 0.7343425609306344, -0.8911558637081078,
#     -1.0051099793265696, -0.12148518423158469, -0.4801968475158174,
#     -0.28910340026287856, 1.6087590765792643, 1.6189552037455606,
#     -0.38763462350750655, -0.3763870260680415, 0.21642633142264128,
#     -0.11024922321249885, -0.12470615670462065, -0.44208308523109213,
#     0.7511112872365361, -0.0077227198151474975, -0.004804749540924683,
#     -0.08948642202040107, -0.09507567152556495, 1.2356940323701657,
#     -0.011663642603760032, -0.036651869142258646, -0.024436507262009306,
#     -0.01238515036740332, -0.02618002418454278, -0.018609896340735923,
#     -0.04122119759327531, -0.0028174939213690777, -0.0975309439715147,
#     -0.7257784945454897, -0.3681102129968653, -0.6372092679572258,
#     -0.6319290328885425, -0.37436223991967527, -0.37443160310530493,
#     0.7712831058493207, -0.349683030873482, -0.37455970440553465,
#     -1.8259911156502953, 1.2587542737799418, 1.0664013456654926,
#     -0.43907816809041417, 2.756092007079775, 0.155090881452997,
#     -0.6395319051152512, -0.6248707997445304, -0.38763462350750655,
#     -0.3763870260680415, 0.6528228780141483
# };

# %%
ytest = y_test[5:15].astype(np.uint8)
print(c_writer.create_array(ytest,"uint8_t","y_test"))
# Out:
# const unsigned int y_test_dim1 = 10;
# const unsigned int y_test_dim2 = 1;
#
# const uint8_t y_test[10][1] = {
#     0, 0, 1, 1, 0, 1, 1, 1, 0, 1
# };
